# %%
import numpy as np
import pandas as pd

# %%
# create empty dataframe
main_df = pd.DataFrame()

# we need to calculate from year 2017-present. upto 2016 data is already present
for year in range(2017, 2023):
    link = 'https://en.wikipedia.org/wiki/List_of_American_films_of_' + str(year)
    
    df1 = pd.read_html(link, header=0)[2]
    df2 = pd.read_html(link, header=0)[3]
    df3 = pd.read_html(link, header=0)[4]
    df4 = pd.read_html(link, header=0)[5]
    
    # append all these
    df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
    
    # append the final dataframe to the main dataframe
    main_df = main_df.append(df, ignore_index=True)

# %%
# let's keep only the title and cast-crew columns
main_df = main_df[['Title', 'Cast and crew']]
main_df = main_df.dropna(how='any')
main_df
# Out:
#                                      Title  \
# 0                   Underworld: Blood Wars
# 1                                  Arsenal
# 2                               Between Us
# 3                           Monster Trucks
# 4                          The Bye Bye Man
# ...                                    ...
# 1434  Are You There God? It's Me, Margaret
# 1435                               Distant
# 1436                   Don't Worry Darling
# 1437          Puss in Boots: The Last Wish
# 1438                                  Bros
#
#                                           Cast and crew
# 0     Anna Foerster (director); Cory Goodman (screen...
# 1     Steven C. Miller (director); Jason Mosberg (sc...
# 2     Rafael Palacio Illingworth (director/screenpla...
# 3     Chris Wedge (director); Derek Connolly (screen...
# 4     Stacy Title (director); Jonathan Penner (scree...
# ...                                                 ...
# 1434  Kelly Fremon Craig (director/screenplay); Abby...
# 1435  Josh Gordon & Will Speck (directors); Spenser ...
# 1436  Olivia Wilde (director); Katie Silberman, Care...
# 1437  Joel Crawford (director); Antonio Banderas, Sa...
# 1438  Nicholas Stoller (director/screenplay); Billy ...
#
# [1419 rows x 2 columns]

# %%
# get genre, original_language and overview
from tmdbv3api import Movie, TMDb
import requests
import json

tmdb = TMDb()
tmdb.api_key = '8cb85690b8c1dfe9317de8b51bafc493'
tmdb_movie = Movie()

def get_respose_json(x):
    result = tmdb_movie.search(x)
    if result == []:
        return {}
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
    data_json = response.json()
    return data_json

def get_genre(x):
    data_json = get_respose_json(x)
    genres = []
    if "genres" in data_json:
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        return np.NaN

def get_overview(x):
    data_json = get_respose_json(x)
    return data_json.get('overview')

def get_original_lang(x):
    data_json = get_respose_json(x)
    return data_json.get('original_language')

def get_id(x):
    data_json = get_respose_json(x)
    return data_json.get('id')


main_df['genres'] = main_df['Title'].map(lambda x: get_genre(str(x)))
main_df['overview'] = main_df['Title'].map(lambda x: get_overview(str(x)))
main_df['original_language'] = main_df['Title'].map(lambda x: get_original_lang(str(x)))
main_df['movie_id'] = main_df['Title'].map(lambda x: get_id(x))

# %%
temp = main_df.head(500)
temp
# Out:
#                               Title  \
# 0            Underworld: Blood Wars
# 1                           Arsenal
# 2                        Between Us
# 3                    Monster Trucks
# 4                   The Bye Bye Man
# ..                              ...
# 495  The Possession of Hannah Grace
# 496         Anna and the Apocalypse
# 497                       Capernaum
# 498             Mary Queen of Scots
# 499                     Ben Is Back
#
#                                          Cast and crew  \
# 0    Anna Foerster (director); Cory Goodman (screen...
# 1    Steven C. Miller (director); Jason Mosberg (sc...
# 2    Rafael Palacio Illingworth (director/screenpla...
# 3    Chris Wedge (director); Derek Connolly (screen...
# 4    Stacy Title (director); Jonathan Penner (scree...
# ..                                                 ...
# 495  Diederik van Rooijen (director); Brian Sieve (...
# 496  John McPhail (director); Alan McDonald, Ryan M...
# 497  Nadine Labaki (director/screenplay); Zain Al R...
# 498  Josie Rourke (director); Beau Willimon (screen...
# 499  Peter Hedges (director/screenplay); Lucas Hedg...
#
#                              genres  \
# 0    Fantasy Action Thriller Horror
# 1                          Thriller
# 2           Romance Adventure Drama
# 3     Action Comedy Science Fiction
# 4                   Horror Thriller
# ..                              ...
# 495                    Horror Drama
# 496           Horror Comedy Fantasy
# 497                           Drama
# 498                   Drama History
# 499                           Drama
#
#                                               overview original_language  \
# 0    Vampire death dealer Selene fends off brutal a...                en
# 1    After the deadbeat brother of a businessman is...                en
# 2    Stranded after a tragic plane crash, two stran...                en
# 3    Tripp is a high school senior with a knack for...                en
# 4    When three college students move into an old h...                en
# ..                                                 ...               ...
# 495  When a cop who is just out of rehab takes the ...                en
# 496  A zombie apocalypse threatens the sleepy town ...                en
# 497  Zain, a 12-year-old boy scrambling to survive ...                ar
# 498  In 1561, Mary Stuart, widow of the King of Fra...                en
# 499  19-year-old Ben Burns unexpectedly returns hom...                en
#
#      movie_id
# 0    346672.0
# 1    388202.0
# 2    290512.0
# 3    262841.0
# 4    292280.0
# ..        ...
# 495  434555.0
# 496  461928.0
# 497  517814.0
# 498  457136.0
# 499  492452.0
#
# [500 rows x 6 columns]

# %%
len(main_df)
# Out:
# 1419

# %%
from copy import deepcopy
X = deepcopy(temp['Cast and crew'][0])
print(X)
Y = deepcopy(temp['Cast and crew'][497])
Y
# Out:
# Anna Foerster (director); Cory Goodman (screenplay); Kate Beckinsale, Theo James, Lara Pulver, James Faulkner, Charles Dance
# 'Nadine Labaki (director/screenplay); Zain Al Rafeea, Yordanos Shiferaw, Boluwatife Treasure Bankole, Kawthar Al Haddad'

# %%
from copy import deepcopy

# # rename the cast and crew to only cast.
# # cast contains actors/actress names in the leading roles.

main_df.rename(columns = {'Cast and crew': 'cast'}, inplace = True)

def get_director(x):
    X = deepcopy(x)
    if "(director)" in x:
        return X.split(" (director); ")[0]
    elif "(directors)" in x:
        return X.split(" (directors); ")[0]
    else:
        return X.split(" (director/screenplay); ")[0]

main_df['crew'] = main_df['cast'].apply(lambda x: get_director(x))

def get_cast(x):
    X = deepcopy(x)
    if "(director/screenplay)" in X:
        try:
            return X.split(' (director/screenplay); ')[1].split(', ')[0]
        except:
            return ""
    if "(director)" in X:
        try:
            X = X.split(" (director); ")[1]
        except:
            return ""
    if "(directors)" in X:
        try:
            X = X.split(" (directors); ")[1]
        except:
            return ""
    try:
        return X.split(' (screenplay); ')[1].split(", ")[0]
    except:
        return ""

main_df['cast'] = main_df['cast'].apply(lambda x: get_cast(x))

# %%
main_df
# Out:
#                                      Title  \
# 0                   Underworld: Blood Wars
# 1                                  Arsenal
# 2                               Between Us
# 3                           Monster Trucks
# 4                          The Bye Bye Man
# ...                                    ...
# 1434  Are You There God? It's Me, Margaret
# 1435                               Distant
# 1436                   Don't Worry Darling
# 1437          Puss in Boots: The Last Wish
# 1438                                  Bros
#
#                                            cast  \
# 0                               Kate Beckinsale
# 1                                Adrian Grenier
# 2                                Olivia Thirlby
# 3                                    Lucas Till
# 4                                 Douglas Smith
# ...                                         ...
# 1434                         Abby Ryder Fortson
# 1435                              Anthony Ramos
# 1436                              Florence Pugh
# 1437
# 1438  Billy Eichner (screenplay); Billy Eichner
#
#                                                genres  \
# 0                      Fantasy Action Thriller Horror
# 1                                            Thriller
# 2                             Romance Adventure Drama
# 3                       Action Comedy Science Fiction
# 4                                     Horror Thriller
# ...                                               ...
# 1434                                     Drama Comedy
# 1435                                          Western
# 1436                           Drama Mystery Thriller
# 1437  Animation Adventure Comedy Family Fantasy Drama
# 1438          Adventure Comedy Family Science Fiction
#
#                                                overview original_language  \
# 0     Vampire death dealer Selene fends off brutal a...                en
# 1     After the deadbeat brother of a businessman is...                en
# 2     Stranded after a tragic plane crash, two stran...                en
# 3     Tripp is a high school senior with a knack for...                en
# 4     When three college students move into an old h...                en
# ...                                                 ...               ...
# 1434  When her family moves from the city to the sub...                en
# 1435  After destroying a Seminole fort, American sol...                en
# 1436  A housewife living in a utopian community in t...                en
# 1437  Puss in Boots discovers that his passion for a...                en
# 1438  Mario and Luigi, plumbers from Brooklyn, find ...                en
#
#       movie_id                        crew
# 0     346672.0               Anna Foerster
# 1     388202.0            Steven C. Miller
# 2     290512.0  Rafael Palacio Illingworth
# 3     262841.0                 Chris Wedge
# 4     292280.0                 Stacy Title
# ...        ...                         ...
# 1434  555285.0          Kelly Fremon Craig
# 1435   61391.0    Josh Gordon & Will Speck
# 1436  619730.0                Olivia Wilde
# 1437  315162.0               Joel Crawford
# 1438    9607.0            Nicholas Stoller
#
# [1419 rows x 7 columns]

# %%
# create the final tag column on which basis we will prepare our model.
main_df['final_tag'] = main_df['overview'] + main_df['original_language']

# %%
final_df = main_df[['Title', 'cast', 'crew', 'genres', 'final_tag', 'movie_id']]
final_df
# Out:
#                                      Title  \
# 0                   Underworld: Blood Wars
# 1                                  Arsenal
# 2                               Between Us
# 3                           Monster Trucks
# 4                          The Bye Bye Man
# ...                                    ...
# 1434  Are You There God? It's Me, Margaret
# 1435                               Distant
# 1436                   Don't Worry Darling
# 1437          Puss in Boots: The Last Wish
# 1438                                  Bros
#
#                                            cast                        crew  \
# 0                               Kate Beckinsale               Anna Foerster
# 1                                Adrian Grenier            Steven C. Miller
# 2                                Olivia Thirlby  Rafael Palacio Illingworth
# 3                                    Lucas Till                 Chris Wedge
# 4                                 Douglas Smith                 Stacy Title
# ...                                         ...                         ...
# 1434                         Abby Ryder Fortson          Kelly Fremon Craig
# 1435                              Anthony Ramos    Josh Gordon & Will Speck
# 1436                              Florence Pugh                Olivia Wilde
# 1437                                                          Joel Crawford
# 1438  Billy Eichner (screenplay); Billy Eichner            Nicholas Stoller
#
#                                                genres  \
# 0                      Fantasy Action Thriller Horror
# 1                                            Thriller
# 2                             Romance Adventure Drama
# 3                       Action Comedy Science Fiction
# 4                                     Horror Thriller
# ...                                               ...
# 1434                                     Drama Comedy
# 1435                                          Western
# 1436                           Drama Mystery Thriller
# 1437  Animation Adventure Comedy Family Fantasy Drama
# 1438          Adventure Comedy Family Science Fiction
#
#                                               final_tag  movie_id
# 0     Vampire death dealer Selene fends off brutal a...  346672.0
# 1     After the deadbeat brother of a businessman is...  388202.0
# 2     Stranded after a tragic plane crash, two stran...  290512.0
# 3     Tripp is a high school senior with a knack for...  262841.0
# 4     When three college students move into an old h...  292280.0
# ...                                                 ...       ...
# 1434  When her family moves from the city to the sub...  555285.0
# 1435  After destroying a Seminole fort, American sol...   61391.0
# 1436  A housewife living in a utopian community in t...  619730.0
# 1437  Puss in Boots discovers that his passion for a...  315162.0
# 1438  Mario and Luigi, plumbers from Brooklyn, find ...    9607.0
#
# [1419 rows x 6 columns]

# %%
final_df.to_csv('Data_2017-2022.csv', index=False)
